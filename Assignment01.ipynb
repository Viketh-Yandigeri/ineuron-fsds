# %% [raw]
# 1. In the below elements which of them are values or an expression? eg:- values can be
# integer or string and expressions will be mathematical operators.
#
# * - Expression(Multiplication operator)
# 'hello' → Value(String)
# -87.8 → Value(Integer)
# -  → Expression(Substraction)
# / → Expression(Division)
# + → Expression(Addition)
# 6 → Value(Integer)

# %% [raw]
# 2. What is the difference between string and variable?
#
# Ans:
#
# Variable is used to store a value(different types of data) in computer memory.
# String is a value which can be represented as text and is enclosed in single or double quotes.

# %% [raw]
# 3. Describe three different data types.
#
# Ans:
# 1. Numeric
# 2. Boolean
# 3. Sequence

# %% [raw]
# 4. What is an expression made up of? What do all expressions do?
# Ans:m
# Expressions consist of combinations of operators and operands.
# Expressions are executed to produce some output.

# %% [raw]
# 5. This assignment statements, like spam = 10. What is the difference between an
# expression and a statement?
#
# Ans:
# →Expression always returns a value after executing the expression.
# Examples: 10*6, print(a+b) etc
#
# →Statements are instructions which donot have a return value.
# Examples: Assignment, for loop, while loop etc

# %% [raw]
# 6. After running the following code, what does the variable bacon contain?
# bacon = 22
# bacon + 1
#
# ans: 22

# %% [raw]
# 7. What should the values of the following two terms be?
# Ans:
# 'spam' + 'spamspam' = 'spamspamspam'
# 'spam' * 3 = 'spamspamspam'

# %% [raw]
# 8. Why is eggs a valid variable name while 100 is invalid?
#
# Ans: Integer can not be assigned with another integer because 100 = 50 is not correct.
# As per defination of variable, name of variable is not allowed to start with numeric value.

# %% [raw]
# 9. What three functions can be used to get the integer, floating-point number, or string
# version of a value?
#
# Ans:
# →int() to get Integer
# →float() to get floating point number
# →str() to get string

# %% [raw]
# 10. Why does this expression cause an error? How can you fix it?
# 'I have eaten' + 99 + 'burritos'
#
# Ans:
#     Addition between different data types not possible. In this example addition of integers data type with string data type is not allowed.
